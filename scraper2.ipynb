# %%
# Load the player bios from the csv

import pandas as pd

df = pd.read_csv('player_bios.csv')

# %%
df
# Out:
#                                              Player Bio
# 0     A physical specimen with a rare size-speed com...
# 1     A legitimate No. 1-caliber receiver who steppe...
# 2     A highly disruptive, athletic specimen with th...
# 3     A havoc-wreaking rush linebacker with the burs...
# 4     Smart, tough, versatile franchise left tackle ...
# ...                                                 ...
# 4993  Webb is a Florida product but helped Stevenson...
# 4994  Russ is the son of Craig Yeast, who was the SE...
# 4995  Marks was known as "Grandpa" on the field as a...
# 4996  Wynn was coached by former Georgia and NFL run...
# 4997  Moala signed with Indiana State and then-head ...
#
# [4998 rows x 1 columns]

# %%
# Remove nas and duplicates

df = df.dropna()

# %%
df
# Out:
#                                              Player Bio
# 0     A physical specimen with a rare size-speed com...
# 1     A legitimate No. 1-caliber receiver who steppe...
# 2     A highly disruptive, athletic specimen with th...
# 3     A havoc-wreaking rush linebacker with the burs...
# 4     Smart, tough, versatile franchise left tackle ...
# ...                                                 ...
# 4993  Webb is a Florida product but helped Stevenson...
# 4994  Russ is the son of Craig Yeast, who was the SE...
# 4995  Marks was known as "Grandpa" on the field as a...
# 4996  Wynn was coached by former Georgia and NFL run...
# 4997  Moala signed with Indiana State and then-head ...
#
# [3877 rows x 1 columns]

# %%
# Drop duplicates

df = df.drop_duplicates()

# %%
df
# Out:
#                                              Player Bio
# 0     A physical specimen with a rare size-speed com...
# 1     A legitimate No. 1-caliber receiver who steppe...
# 2     A highly disruptive, athletic specimen with th...
# 3     A havoc-wreaking rush linebacker with the burs...
# 4     Smart, tough, versatile franchise left tackle ...
# ...                                                 ...
# 4993  Webb is a Florida product but helped Stevenson...
# 4994  Russ is the son of Craig Yeast, who was the SE...
# 4995  Marks was known as "Grandpa" on the field as a...
# 4996  Wynn was coached by former Georgia and NFL run...
# 4997  Moala signed with Indiana State and then-head ...
#
# [3875 rows x 1 columns]
